# %%
from google.colab import drive
drive.mount('/content/drive')
# !git config --global user.name "Huseyin"
# !git config --global user.email "huseyinozgurkazan@gmail.com"

# %%
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/hsyni/machinelearning.git
# !git push -u origin main
